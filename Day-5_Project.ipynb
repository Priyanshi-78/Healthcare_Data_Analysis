# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("healthcare_dataset.csv")
print(df)
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  str
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  str
#  3   Blood Type          55500 non-null  str
#  4   Medical Condition   55500 non-null  str
#  5   Date of Admission   55500 non-null  str
#  6   Doctor              55500 non-null  str
#  7   Hospital            55500 non-null  str
#  8   Insurance Provider  55500 non-null  str
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  str
#  12  Discharge Date      55500 non-null  str
#  13  Medication          55500 non-null  str
#  14  Test Results        55500 non-null  str
# dtypes: float64(1), int64(2), str(12)
# memory usage: 6.4 MB

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='str')

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.dtypes
# Out:
# Name                      str
# Age                     int64
# Gender                    str
# Blood Type                str
# Medical Condition         str
# Date of Admission         str
# Doctor                    str
# Hospital                  str
# Insurance Provider        str
# Billing Amount        float64
# Room Number             int64
# Admission Type            str
# Discharge Date            str
# Medication                str
# Test Results              str
# dtype: object

# %% [markdown]
# 1.Which medical condition has the highest average billing amount?

# %%
condition_bill = (df.groupby("Medical Condition")["Billing Amount"].mean().sort_values(ascending=False))
print(condition_bill)
# Out:
# Medical Condition
# Obesity         25805.971259
# Diabetes        25638.405577
# Asthma          25635.249359
# Arthritis       25497.327056
# Hypertension    25497.095761
# Cancer          25161.792707
# Name: Billing Amount, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    x=condition_bill.index,
    y=condition_bill.values,
    palette="viridis"
)
plt.title("Average Billing Amount by Medical Condition")
plt.xlabel("Medical Condition")
plt.ylabel("Average Billing Amount")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\2364349264.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 2.Which insurance provider has the highest total billing amount?

# %%
insurance_bill = (df.groupby("Insurance Provider")["Billing Amount"].sum().sort_values(ascending=False))
print(insurance_bill)
# Out:
# Insurance Provider
# Cigna               2.871393e+08
# Medicare            2.857208e+08
# Blue Cross          2.832543e+08
# UnitedHealthcare    2.824545e+08
# Aetna               2.788631e+08
# Name: Billing Amount, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(
    x=insurance_bill.index,
    y=insurance_bill.values,
    palette="rocket"
)
plt.title("Total Billing Amount by Insurance Provider")
plt.xlabel("Insurance Provider")
plt.ylabel("Total Billing Amount")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\2092330270.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 3.What is the average length of hospital stay for each admission type?

# %%
df["Date of Admission"] = pd.to_datetime(df["Date of Admission"])
df["Discharge Date"] = pd.to_datetime(df["Discharge Date"])

df["Hospital Stay"] = (df["Discharge Date"] - df["Date of Admission"]).dt.days
avg_stay = (df.groupby("Admission Type")["Hospital Stay"].mean().sort_values(ascending=False))
print(avg_stay)
# Out:
# Admission Type
# Emergency    15.595052
# Elective     15.525328
# Urgent       15.408000
# Name: Hospital Stay, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    x=avg_stay.index,
    y=avg_stay.values,
    palette="Set2"
)
plt.title("Average Hospital Stay by Admission Type")
plt.xlabel("Admission Type")
plt.ylabel("Average Hospital Stay (Days)")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\3099645801.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 4.Which hospital treated the highest number of patients?

# %%
hospital = (df["Hospital"].value_counts().head(10))
print(hospital)
# Out:
# Hospital
# LLC Smith      44
# Ltd Smith      39
# Johnson PLC    38
# Smith Ltd      37
# Smith PLC      36
# Smith Group    36
# Johnson Inc    35
# Smith Inc      34
# Smith LLC      32
# Group Smith    32
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    x=hospital.values,
    y=hospital.index,
    palette="magma"
)
plt.title("Top 10 Hospitals by Number of Patients")
plt.xlabel("Number of Patients")
plt.ylabel("Hospital")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\4259322592.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 5.Which age group (0–20, 21–40, 41–60, 61+) contributes the highest total billing?

# %%
bins = [0,20,40,60,100]
labels = ["0-20","21-40","41-60","61+"]
df["Age Group"] = pd.cut(df["Age"],bins=bins,labels=labels)

age_bill = (df.groupby("Age Group")["Billing Amount"].sum())
print(age_bill)
# Out:
# Age Group
# 0-20     6.336431e+07
# 21-40    4.141998e+08
# 41-60    4.209816e+08
# 61+      5.188863e+08
# Name: Billing Amount, dtype: float64

# %%
plt.figure(figsize=(6,5))
sns.barplot(
    x=age_bill.index,
    y=age_bill.values,
    palette="coolwarm"
)
plt.title("Total Billing by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Total Billing")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\3555405492.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 6.Which doctor generated the highest total hospital revenue?

# %%
doctor = (df.groupby("Doctor")["Billing Amount"].sum().sort_values(ascending=False).head(10))
print(doctor)
# Out:
# Doctor
# Michael Smith      784501.843132
# Robert Smith       634792.990831
# John Smith         610109.604175
# Robert Johnson     524193.003178
# David Smith        473345.609187
# William Johnson    469198.116030
# John Johnson       466769.966463
# James Smith        461817.900317
# Michael Johnson    460819.038528
# David Johnson      445605.542275
# Name: Billing Amount, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    x=doctor.values,
    y=doctor.index,
    palette="flare"
)
plt.title("Top 10 Doctors by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Doctor")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\2116686062.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 7.What percentage of patients have Normal, Abnormal, and Inconclusive test results?

# %%
test = df["Test Results"].value_counts()
percentage = (test / len(df)) * 100
print(percentage)
# Out:
# Test Results
# Abnormal        33.562162
# Normal          33.363964
# Inconclusive    33.073874
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.pie(
    percentage,
    labels=percentage.index,
    autopct="%1.1f%%",
    startangle=90
)
plt.title("Percentage of Test Results")
plt.show()

# %% [markdown]
# 8.Which medical condition has the longest average hospital stay?

# %%
condition_stay = (df.groupby("Medical Condition")["Hospital Stay"].mean().sort_values(ascending=False))
print(condition_stay)
# Out:
# Medical Condition
# Asthma          15.696570
# Arthritis       15.517404
# Cancer          15.495827
# Obesity         15.464305
# Hypertension    15.458626
# Diabetes        15.422936
# Name: Hospital Stay, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    x=condition_stay.index,
    y=condition_stay.values,
    palette="Spectral"
)
plt.title("Average Hospital Stay by Medical Condition")
plt.xlabel("Medical Condition")
plt.ylabel("Average Stay")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\2444784106.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# 9.Which medication is prescribed most frequently for each medical condition?

# %%
medication = (df.groupby(["Medical Condition","Medication"]).size().reset_index(name="Count"))
top_medication = medication.loc[medication.groupby("Medical Condition")["Count"].idxmax()]
print(top_medication)
# Out:
#    Medical Condition   Medication  Count
# 0          Arthritis      Aspirin   1918
# 8             Asthma  Paracetamol   1888
# 12            Cancer      Lipitor   1922
# 17          Diabetes      Lipitor   1893
# 21      Hypertension    Ibuprofen   1893
# 29           Obesity   Penicillin   1893

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=top_medication,
    x="Medical Condition",
    y="Count",
    palette="Set1")

plt.title("Most Prescribed Medication by Medical Condition")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10604\3637870101.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_medication,

# %% [markdown]
# 10.Identify the top 10 patients with the highest billing amounts and analyze their common characteristics.

# %%
top_10=df[['Name','Billing Amount','Age','Insurance Provider']].sort_values(by='Billing Amount',ascending=False).head(10)
print(top_10)
# Out:
#                    Name  Billing Amount  Age Insurance Provider
# 36349     tOdd CARrILlO    52764.276736   51         Blue Cross
# 34613       kARen klInE    52373.032374   79   UnitedHealthcare
# 51313       kARen klInE    52373.032374   74   UnitedHealthcare
# 5735     DAVId SanDOvaL    52271.663747   22         Blue Cross
# 7088   kathRYN GoNzales    52211.852966   18              Aetna
# 1574     BRETT mARshAll    52181.837792   42              Aetna
# 6663        LAuRie hOod    52170.036854   42              Cigna
# 52826       LAuRie hOod    52170.036854   43              Cigna
# 33117      JUstIn CLark    52154.237722   53   UnitedHealthcare
# 34368      sCotT pOWElL    52102.240889   38              Cigna

# %%
plt.figure(figsize=(10,5))
sns.barplot(
    data=top_10,
    y='Billing Amount',
    x='Name',
    hue='Insurance Provider',
    palette="viridis"
)
plt.title("Top 10 Patients by Billing Amount")
plt.xlabel("Patient")
plt.ylabel("Billing Amount")
plt.xticks(rotation=90)
plt.show()
